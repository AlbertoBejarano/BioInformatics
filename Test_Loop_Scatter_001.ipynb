# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt
import autograd.numpy as np
import seaborn as sns
import pandas as pd

# %%
data  =  './data/matrixdata.csv'

# %%
df  =  pd.read_csv(data, sep='\t',index_col=False)

# %%
df.head(3)
# Out:
#    x  y  Gene_1  Gene_2  Gene_3  Gene_4
# 0  1  1       1     100       1     100
# 1  2  1       2      99      11      90
# 2  3  1       3      98      21      80

# %%
fig, ax = plt.subplots(figsize=(25, 25), dpi=150, subplot_kw={'aspect': 'equal'})
plt.subplots_adjust(wspace=0.02, hspace=0.01)
#plt.subplots(figsize=(25, 50))
count = 1
for i in range(len(df.columns)+2):
    plt.subplot(2, 2, count)
    x = df.x; y = df.y; col = df.columns[i+2];  c = df[col].tolist()
    sns.scatterplot(x = x, y = y, data = df, s=2000, c = c, cmap="coolwarm", linewidth=0.005)
    plt.xticks(rotation=0, fontsize = 30); plt.yticks(rotation=0, fontsize = 30)
    plt.xlabel("UMAP 1",fontsize=25, labelpad=15); plt.ylabel("UMAP 2",fontsize=25, labelpad=15)
    plt.title(col, fontsize=50, pad=20)
    if count == len(df.columns)-2:
            break
    count += 1

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()
g = sns.scatterplot(x = x, y = y, data = df, c=df.Gene_2, legend="full", ax=ax)
g.legend(loc='upper right', bbox_to_anchor=(1.2, 1.0), ncol=1)

norm = plt.Normalize(df.Gene_2.min(), df.Gene_2.max())
cmap = sns.cubehelix_palette(light=1, as_cmap=True)

sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm); sm.set_array([])
cax = fig.add_axes([ax.get_position().x1+0.05, ax.get_position().y0, 0.06, ax.get_position().height / 2])
ax.figure.colorbar(sm, cax=cax)

plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
sns.scatterplot(x = x, y = y, data = df, s=100, c = df.Gene_1, cmap="coolwarm", linewidth=0.005)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
g = sns.scatterplot(data = df, x = "x", y = "y", hue = "Gene_1", size ="Gene_4")
g.legend(loc='center left', bbox_to_anchor=(1, 0.5), ncol=1)
